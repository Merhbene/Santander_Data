# %%
import pandas as pd
import requests
import re
import json
from bs4 import BeautifulSoup

url = 'https://finance.yahoo.com/quote/AAPL/analysis?p=AAPL'
page = requests.get(url)
soup = BeautifulSoup(page.content, "lxml")

# %%
script = soup.find('script', text=re.compile('root\.App\.main'))
script
# Out:
# <script>
# (function (root) {
# /* -- Data -- */
# root.App || (root.App = {});
# root.App.now = 1624977446006;
# root.App.main = {"context":{"dispatcher":{"stores":{"PageStore":{"currentPageName":"quote","currentEvent":{"eventName":"NEW_PAGE_SUCCESS"},"currentRenderTargetId":"default","pagesConfigRaw":{"base":{"quote":{"layout":{"bundleName":"yahoodotcom-layout.TwoColumnLayout","name":"TwoColumnLayout","config":{"enableHeaderCollapse":true,"additionalBodyWrapperClasses":"Bgc($layoutBgColor)!","contentWrapperClasses":"Bgc($lv2BgColor)!","Header":{"isFixed":true,"uhContainerClasses":"Bgi($uhGrayGradient) D(n)--print","navContainerClasses":"Bgi($navrailGrayGradient) Bxsh($navrailShadow) Pos(r) hasScrolled_Bxsh(headerShadow) Panel-open_Bxsh(headerShadow)","navTransitionClasses":"HideNavrail_Translate3d(0,-46px,0) Panel-open_Translate3d(0,-46px,0)","secondaryNavContainerClasses":"hasScrolled_Bdbw(0px) Bgc($lv3BgColor) Bxsh($navrailShadow) D(n)--print","height":135},"fetchNewAttribution":true},"meta":{"property":{"twitter:site":"@YahooFinance"}}},"meta":{"property":{"twitter:site":"@YahooFinance","fb:pages":"458584288257241","og:image":"https:\u002F\u002Fs.yimg.com\u002Fcv\u002Fapiv2\u002Fsocial\u002Fimages\u002Fyahoo_default_logo.png"}},"enablePremium":true,"isHighValueUser":false,"videoOverrides":{"enableOathPlayer":true},"regions":{"UH":[{"bundleName":"tdv2-wafer-header.finance","name":"HeaderDesktop","perfLabel":"WaferHeaderDesktop","critical":true,"config":{"logo":{"brandName":"YAHOO_FINANCE","enableHeading":false,"link":"https:\u002F\u002Ffinance.yahoo.com","imageUri":"https:\u002F\u002Fs.yimg.com\u002Frz\u002Fp\u002Fyahoo_finance_en-US_s_f_pw_351X40_finance_2x.png","theme":{"heading":"Fz(0) Pstart(15px) Pos(a) Miw(190px)","link":"Bgp(0) Bgr(nr) Bgz(702px) D(b) H(35px) W(92px)  Bgz(702px)!--sm1024 Cur(p) Mx(a)","linkLabel":"Hidden"}},"mailMenu":{"i13n":{"sec":"uh","subsec":"mail","t1":null,"t2":null,"slk":"mail","elm":"btn","itc":"0"},"mailLink":"","signInUrl":"https:\u002F\u002Flogin.yahoo.com\u002Fconfig\u002Flogin?.src=finance&.intl=us&.lang=en-US&.done=https:\u002F\u002Ffinance.yahoo.com&activity=uh-mail","xhrPathPrefix":"\u002F_finance_doubledown","theme":{"button":"C(#4d00ae) D(b) H(22px) Lh(22px) Py(7px) Pos(r) Td(n)","buttonLabel":"D(ib) Fz(14px) Fw(b) Lh(24px) Pstart(38px)","icon":"Pos(a) T(4px)","loadingImage":"D(b) M(a) P(20px)","menuElement":"D(ib) H(46px) Mstart(14px) Mt(7px) O(n) Va(t)","menuPanel":"Bgc(#fff) Bdc(#d6d6da) Bdrs(6px) Bds(s) Bdw(1px) Bxsh($menuShadow) Fz(14px) List(n) Mt(10px) Mah(0) Mih(57px) Op(0) P(0) Pos(a) End(0) Trs($fastMenuTransition) V(h) W(382px) active_Mah(478px) active_Op(1) active_V(v)","menuPanelSignIn":"Bgc(#fff) Bdc(#d6d6da) Bdrs(6px) Bds(s) Bdw(1px) Bxsh($menuShadow) Fz(14px) List(n) Mt(10px) Mah(0) Mih(57px) Op(0) P(0) Pos(a) End(0) Trs($menuTransition) V(h) W(382px) active_Mah(614px) active_Op(1) active_V(v)","menuPanelSignedOut":"Bgc(#fff) Bdc(#d6d6da) Bdrs(6px) Bds(s) Bdw(1px) Bxsh($menuShadow) Bxz(bb) Fz(14px) List(n) Mt(10px) Mah(0) Mih(57px) Op(0) Px(24px) Py(20px) Pos(a) End(0) Ta(c) Trs($menuTransition) V(h) W(382px) active_Mah(60px) active_Op(1) active_V(v)","menuPanelPromoSignedOut":"Bgc(#fff) Bdc(#d6d6da) Bdrs(6px) Bds(s) Bdw(1px) Bxsh($menuShadow) Bxz(bb) Fz(14px) List(n) Mt(10px) Mah(0) Mih(57px) Op(0) Px(24px) Py(20px) Pos(a) End(0) Ta(c) Trs($menuTransition) V(h) W(382px) active_Mah(172px) active_Op(1) active_V(v)","signInLink":"C(#0078ff) Fw(b) Td(n)","promoContainer":"D(f) Ta(start) Ai(c) Pt(20px) Pb(10px) Pos(r)","promoImg":"W(53px) H(59px) Mend(14px)","promoHeader":"Fz(13px) Fw(b) Mb(0) C($c-fuji-inkwell)","promoContent":"Fz(13px) C(#59636d) Mt(5px) Mb(5px)","promoLink":"Fz(13px) C($c-fuji-smurfette) Fw(b) Td(n)","_iconColor":"#6001d2","_iconHeight":"30","_iconWidth":"30"}},"mrt":{"cache":false,"static":true,"enableStaticI13nTracking":false},"navigationBar":{"enabled":false},"notificationMenu":{"enabled":true,"badge":{"data-wf-state-text":"[state.financeNotification.unreadCount]","data-wf-toggle-class":"stateChange:toggle:D(n)","data-wf-state-key":"[state.financeNotificatio ...
# }(this));
# </script>

# %%
json_text = re.search(r'^\s*root\.App\.main\s*=\s*({.*?})\s*;\s*$',
                      script.string, flags=re.MULTILINE).group(1)
data = json.loads(json_text)
data
# Out:
# {'context': {'dispatcher': {'stores': {'AdStore': {'_childCompositeReady': {},
#      '_newPageRendered': False,
#      'adBoostGroupConf': {'LREC3': None,
#       'LREC3-9': {'extrapositions': ['MON2-9'], 'inview': 'LREC4-9'},
#       'LREC4': None,
#       'LREC4-9': {'extrapositions': ['MON2-9'], 'inview': 'LREC3-9'},
#       'MON2': {'extrapositions': ['LREC3', 'LREC4']},
#       'MON2-9': {'extrapositions': ['LREC3-9', 'LREC4-9']}},
#      'adFetchEvent': {'launchViewportAdSlot': [],
#       'optionalps': '',
#       'ps': 'FB2A,FB2B,FB2C,FB2D,MON,LDRB,LREC,LREC2,FOOT,TRADENOW',
#       'sa': ' ticker=AAPL Y-BUCKET=finance-US-en-US-def LREC=300x250,1x1 rs="pt:utility;site:finance;ver:ydotcom;pct:qsp;lu:0" migration=1',
#       'site': 'finance',
#       'sp': 95993639},
#      'adblockPos': True,
#      'adfetchTimeout': 500,
#      'adsMeta': None,
#      'allowHostUrlAsReferrer': True,
#      'appConfig': {'base': {'aboveFoldPositions': 'WPS,MAST,LDRB,SPRZ,SPL,LREC,BTN,BTN-1,BTN-2,BTN-3,BTN1,BTNA,BTNB,BTNC,BTND,FB2,FB2-1,FB2-2,FB2-3,FB2A,FB2B,FB2C,FB2D,NE4,NE4-1,NE4-2,NE4-3,NE4A,NE4B,NE4C,NE4D',
#        'adBoostGroupConf': {'LREC3': {'extrapositions': ['MON2'],
#          'inview': 'LREC4'},
#         'LREC3-9': {'extrapositions': ['MON2-9'], 'inview': 'LREC4-9'},
#         'LREC4': {'extrapositions': ['MON2'], 'inview': 'LREC3'},
#         'LREC4-9': {'extrapositions': ['MON2-9'], 'inview': 'LREC3-9'},
#         'MON2': {'extrapositions': ['LREC3', 'LREC4']},
#         'MON2-9': {'extrapositions': ['LREC3-9', 'LREC4-9']}},
#        'adblockPos': 1,
#        'allowHostUrlAsReferrer': True,
#        'autoRotation': 10000,
#        'autoadrender': True,
#        'cacheDarlaAsset': True,
#        'cacheDarlaConfig': True,
#        'checkForModalClose': True,
#        'darlaAssetFetch': True,
#        'darlaConfigFetch': True,
#        'darlaJsAtTop': True,
#        'darlaVersion': '4-7-1',
#        'debug': False,
#        'detectAdblock': True,
#        'disableDocDomain': True,
#        'dm': 1,
#        'enableUBAMON': True,
#        'events': {'AUTO': {'autoDDG': 1,
#          'autoIV': 1,
#          'autoMax': 25,
#          'autoRT': 10000,
#          'autoStart': 1,
#          'ddd': 0,
#          'groups': {'LREC3': 'MON2',
#           'LREC3-9': 'MON2-9',
#           'LREC4': 'MON2',
#           'LREC4-9': 'MON2-9',
#           'MON2': 'LREC3,LREC4',
#           'MON2-9': 'LREC3-9,LREC4-9'},
#          'name': 'AUTO',
#          'npv': 1,
#          'ps': {'BTN': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'BTN-1': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'BTN-2': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'BTN-3': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'BTN-5': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'BTN-6': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'BTN-7': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'BTN-8': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'BTN1': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'BTNA': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'BTNB': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'BTNC': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'BTND': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'FB2': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'FB2-1': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'FB2-2': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'FB2-3': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'FB2A': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'FB2B': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'FB2C': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'FB2D': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LDRB': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LDRB-9': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LDRB2': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LDRB2-1': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LDRB2-2': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LDRB2-9': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LREC': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LREC-9': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LREC2': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LREC2-4': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LREC2-5': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LREC2-6': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LREC2-7': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LREC2-8': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LREC2-9': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LREC3': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LREC3-4': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LREC3-5': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LREC3-6': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LREC3-7': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LREC3-8': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LREC3-9': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LREC4': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'LREC4-9': {'autoIV': 1, 'autoMax': 25, 'autoRT': '35000'},
#           'MAST': {'autoIV': 1, 'autoMax': 25, 'autoRT': 30000},
#           'MAST-9': {'autoIV': 1, 'autoMax': 25, 'autoRT': 30000},
#           'MON': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'MON-1': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'MON2': {'autoRT': 10000},
#           'MON2-9': {'autoRT': 10000},
#           'NE4': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'NE4-1': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'NE4-2': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'NE4-3': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'NE4A': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'NE4B': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'NE4C': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'NE4D': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'SCREC': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#           'SPL': {'autoIV': 1, 'autoMax': 25, 'autoRT': 30000},
#           'TRADENOW': {'autoIV': 1, 'autoMax': 0, 'autoRT': 3600000},
#           'TRADENOW-1': {'autoIV': 1, 'autoMax': 0, 'autoRT': 3600000},
#           'WIDGET': {'autoIV': 1, 'autoMax': 0, 'autoRT': 3600000},
#           'WIDGET-1': {'autoIV': 1, 'autoMax': 0, 'autoRT': 3600000},
#           'WPS': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000}}},
#         'DEFAULT': {'secure': 1, 'sp': 1183300002, 'ssl': 1},
#         'adFetch': {'dynamic': True,
#          'name': 'adFetch',
#          'viewportOnly': 'MAST,LDRB,LDRB2,LREC,LREC2,MON,FB2,FB2-1,FB2-2,FB2-3,BTN,BTN-1,BTN-2,BTN-3,BTN1,NE4,NE4-1,NE4-2,NE4-3,WIDGET-1'}},
#        'firstRenderingVisible': True,
#        'k2': {'res': {'pos': ['BTN',
#           'BTN-1',
#           'BTN-2',
#           'BTN-3',
#           'BTN1',
#           'LREC',
#           'LREC2',
#           'LREC3',
#           'LDRB',
#           'MAST'],
#          'rate': 5}},
#        'multipleRenderTargets': True,
#        'nukeAds': 'LREC,LREC2,LREC-9,LREC2-9,LREC3-9,LREC4-9,LDRB-9,MAST-9,MON-1,SPL',
#        'positions': {'BTN': {'clean': 'cleanBTN',
#          'dest': 'destBTN',
#          'h': 60,
#          'id': 'BTN',
#          'metaSize': True,
#          'w': 120},
#         'BTN-1': {'clean': 'cleanBTN-1',
#          'dest': 'destBTN-1',
#          'h': 60,
#          'id': 'BTN-1',
#          'w': 120},
#         'BTN-2': {'clean': 'cleanBTN-2',
#          'dest': 'destBTN-2',
#          'h': 60,
#          'id': 'BTN-2',
#          'metaSize': True,
#          'w': 120},
#         'BTN-3': {'clean': 'cleanBTN-3',
#          'dest': 'destBTN-3',
#          'h': 60,
#          'id': 'BTN-3',
#          'metaSize': True,
#          'w': 120},
#         'BTN-5': {'clean': 'cleanBTN-5',
#          'dest': 'destBTN-5',
#          'h': 60,
#          'id': 'BTN-5',
#          'metaSize': True,
#          'w': 120},
#         'BTN-6': {'clean': 'cleanBTN-6',
#          'dest': 'destBTN-6',
#          'h': 60,
#          'id': 'BTN-6',
#          'metaSize': True,
#          'w': 120},
#         'BTN-7': {'clean': 'cleanBTN-7',
#          'dest': 'destBTN-7',
#          'h': 60,
#          'id': 'BTN-7',
#          'metaSize': True,
#          'w': 120},
#         'BTN-8': {'clean': 'cleanBTN-8',
#          'dest': 'destBTN-8',
#          'h': 60,
#          'id': 'BTN-8',
#          'metaSize': True,
#          'w': 120},
#         'BTN1': {'clean': 'cleanBTN1',
#          'dest': 'destBTN1',
#          'h': 60,
#          'id': 'BTN1',
#          'metaSize': True,
#          'w': 120},
#         'BTN1-1': {'clean': 'cleanBTN1-1',
#          'dest': 'destBTN1-1',
#          'h': 60,
#          'id': 'BTN1',
#          'metaSize': True,
#          'w': 120},
#         'BTNA': {'clean': 'cleanBTNA',
#          'dest': 'destBTNA',
#          'h': 60,
#          'id': 'BTNA',
#          'metaSize': True,
#          'w': 120},
#         'BTNB': {'clean': 'cleanBTNB',
#          'dest': 'destBTNB',
#          'h': 60,
#          'id': 'BTNB',
#          'metaSize': True,
#          'w': 120},
#         'BTNC': {'clean': 'cleanBTNC',
#          'dest': 'destBTNC',
#          'h': 60,
#          'id': 'BTNC',
#          'metaSize': True,
#          'w': 120},
#         'BTND': {'clean': 'cleanBTND',
#          'dest': 'destBTND',
#          'h': 60,
#          'id': 'BTND',
#          'metaSize': True,
#          'w': 120},
#         'DEFAULT': {'enable': True,
#          'fallback': None,
#          'metaSize': False,
#          'name': 'DEFAULT',
#          'staticLayout': False},
#         'FB2': {'clean': 'cleanFB2',
#          'dest': 'destFB2',
#          'h': 60,
#          'id': 'FB2',
#          'metaSize': True,
#          'w': 120},
#         'FB2-1': {'clean': 'cleanFB2-1',
#          'dest': 'destFB2-1',
#          'h': 60,
#          'id': 'FB2-1',
#          'metaSize': True,
#          'w': 120},
#         'FB2-2': {'clean': 'cleanFB2-2',
#          'dest': 'destFB2-2',
#          'h': 60,
#          'id': 'FB2-2',
#          'metaSize': True,
#          'w': 120},
#         'FB2-3': {'clean': 'cleanFB2-3',
#          'dest': 'destFB2-3',
#          'h': 60,
#          'id': 'FB2-3',
#          'metaSize': True,
#          'w': 120},
#         'FB2A': {'clean': 'cleanFB2A',
#          'dest': 'destFB2A',
#          'h': 60,
#          'id': 'FB2A',
#          'metaSize': True,
#          'w': 120},
#         'FB2B': {'clean': 'cleanFB2B',
#          'dest': 'destFB2B',
#          'h': 60,
#          'id': 'FB2B',
#          'metaSize': True,
#          'w': 120},
#         'FB2C': {'clean': 'cleanFB2C',
#          'dest': 'destFB2C',
#          'h': 60,
#          'id': 'FB2C',
#          'metaSize': True,
#          'w': 120},
#         'FB2D': {'clean': 'cleanFB2D',
#          'dest': 'destFB2D',
#          'h': 60,
#          'id': 'FB2D',
#          'metaSize': True,
#          'w': 120},
#         'FOOT': {'clean': 'cleanFOOT',
#          'dest': 'destFOOT',
#          'fr': 'expIfr_exp',
#          'id': 'FOOT'},
#         'FSRVY': {'clean': 'cleanFSRVY',
#          'dest': 'destFSRVY',
#          'fr': 'expIfr_exp',
#          'id': 'FSRVY'},
#         'INARTICLE': {'autoFetch': False,
#          'enable': True,
#          'flex': {'h': {'min': 5}, 'ratio': '1.78x1', 'w': {'min': 10}},
#          'fr': 'expIfr_exp',
#          'h': 211,
#          'id': 'INARTICLE',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 1, 'exp-push': 1},
#          'w': 375,
#          'z': 9},
#         'LDRB': {'clean': 'cleanLDRB',
#          'dest': 'destLDRB',
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 90,
#          'id': 'LDRB',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 1, 'exp-push': 1},
#          'w': 728},
#         'LDRB-9': {'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 90,
#          'id': 'LDRB-9',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 1, 'exp-push': 1},
#          'w': 728},
#         'LDRB2': {'clean': 'cleanLDRB2',
#          'dest': 'destLDRB2',
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 90,
#          'id': 'LDRB2',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 1, 'exp-push': 1},
#          'w': 728},
#         'LDRB2-1': {'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 90,
#          'id': 'LDRB2-1',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 1, 'exp-push': 1},
#          'w': 728},
#         'LDRB2-2': {'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 90,
#          'id': 'LDRB2-2',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 1, 'exp-push': 1},
#          'w': 728},
#         'LDRB2-3': {'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 90,
#          'id': 'LDRB2-3',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 1, 'exp-push': 1},
#          'w': 728},
#         'LDRB2-4': {'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 90,
#          'id': 'LDRB2-4',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 1, 'exp-push': 1},
#          'w': 728},
#         'LREC': {'clean': 'cleanLREC',
#          'dest': 'destLREC',
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'LREC',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300},
#         'LREC-9': {'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'LREC-9',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300},
#         'LREC2': {'clean': 'cleanLREC2',
#          'dest': 'destLREC2',
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'LREC2',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300},
#         'LREC2-4': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'LREC2-4',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300,
#          'z': 9},
#         'LREC2-5': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'LREC2-5',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300,
#          'z': 9},
#         'LREC2-6': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'LREC2-6',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300,
#          'z': 9},
#         'LREC2-7': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'LREC2-7',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300,
#          'z': 9},
#         'LREC2-8': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'LREC2-8',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300,
#          'z': 9},
#         'LREC2-9': {'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'LREC2-9',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300},
#         'LREC3': {'clean': 'cleanLREC3',
#          'dest': 'destLREC3',
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'LREC3',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300},
#         'LREC3-4': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'LREC3-4',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300,
#          'z': 9},
#         'LREC3-5': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'LREC3-5',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300,
#          'z': 9},
#         'LREC3-6': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'LREC3-6',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300,
#          'z': 9},
#         'LREC3-7': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'LREC3-7',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300,
#          'z': 9},
#         'LREC3-8': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'LREC3-8',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300,
#          'z': 9},
#         'LREC3-9': {'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'LREC3-9',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300},
#         'LREC4': {'clean': 'cleanLREC4',
#          'dest': 'destLREC4',
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'LREC4',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300},
#         'LREC4-9': {'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'LREC4-9',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300},
#         'MAST': {'clean': 'cleanMAST',
#          'closeBtn': {'adc': 0, 'mode': 2, 'useShow': 1},
#          'dest': 'destMAST',
#          'fdb': False,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'MAST',
#          'metaSize': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1, 'resize-to': 1},
#          'w': 970},
#         'MAST-9': {'closeBtn': {'adc': 0, 'mode': 2, 'useShow': 1},
#          'fdb': False,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'MAST-9',
#          'metaSize': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1, 'resize-to': 1},
#          'w': 970},
#         'MOMENTS': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'flex': {'h': {'min': 568}, 'ratio': '1x1.78', 'w': {'min': 320}},
#          'fr': 'expIfr_exp',
#          'h': 667,
#          'id': 'MOMENTS',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 1, 'exp-push': 1, 'resize-to': 1},
#          'w': 375,
#          'z': 3},
#         'MON': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 600,
#          'id': 'MON',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 1, 'exp-push': 1, 'resize-to': 1},
#          'w': 300},
#         'MON-1': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 600,
#          'id': 'MON-1',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 1, 'exp-push': 1, 'resize-to': 1},
#          'w': 300},
#         'MON2': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 600,
#          'id': 'MON2',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 1, 'exp-push': 1, 'resize-to': 1},
#          'w': 300},
#         'MON2-9': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 600,
#          'id': 'MON2-9',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 1, 'exp-push': 1, 'resize-to': 1},
#          'w': 300},
#         'NE4': {'clean': 'cleanNE4',
#          'dest': 'destNE4',
#          'h': 60,
#          'id': 'NE4',
#          'metaSize': True,
#          'w': 120},
#         'NE4-1': {'clean': 'cleanNE4-1',
#          'dest': 'destNE4-1',
#          'h': 60,
#          'id': 'NE4-1',
#          'metaSize': True,
#          'w': 120},
#         'NE4-2': {'clean': 'cleanNE4-2',
#          'dest': 'destNE4-2',
#          'h': 60,
#          'id': 'NE4-2',
#          'metaSize': True,
#          'w': 120},
#         'NE4-3': {'clean': 'cleanNE4-3',
#          'dest': 'destNE4-3',
#          'h': 60,
#          'id': 'NE4-3',
#          'metaSize': True,
#          'w': 120},
#         'NE4A': {'clean': 'cleanNE4A',
#          'dest': 'destNE4A',
#          'h': 60,
#          'id': 'NE4A',
#          'metaSize': True,
#          'w': 120},
#         'NE4B': {'clean': 'cleanNE4B',
#          'dest': 'destNE4B',
#          'h': 60,
#          'id': 'NE4B',
#          'metaSize': True,
#          'w': 120},
#         'NE4C': {'clean': 'cleanNE4C',
#          'dest': 'destNE4C',
#          'h': 60,
#          'id': 'NE4C',
#          'metaSize': True,
#          'w': 120},
#         'NE4D': {'clean': 'cleanNE4D',
#          'dest': 'destNE4D',
#          'h': 60,
#          'id': 'NE4D',
#          'metaSize': True,
#          'w': 120},
#         'SCREC': {'clean': 'cleanSCREC',
#          'dest': 'destSCREC',
#          'h': 65,
#          'id': 'SCREC',
#          'w': 300},
#         'SPL': {'autoFetch': False,
#          'css': '.Mags-FontA{font-family:"HelveticaNeue",Helvetica,Arial,sans-serif;font-weight:300;}.Mags-FontA.Size1{font-size:13px;}.Mags-FontA.Size2{font-size:16px;}.Mags-FontA.Size3{font-size:20px;}.Mags-FontA.Size4{font-size:22px;}.Mags-FontA.Size5{font-size:33px;}.Mags-FontA.Size6{font-size:35px;}.Mags-FontA.Size7{font-size:58px;}.Mags-FontA.Size8{font-size:70px;}.Mags-FontA.Size9{font-size:100px;}.Mags-FontB{font-family:Georgia,Times,serif;font-weight:400;}.Mags-FontB.Size1{font-size:18px;}.Mags-FontC{font-family:"HelveticaNeue",Helvetica,Arial,sans-serif;font-weight:400;}.Mags-FontC.Size1{font-size:11px;}.Mags-FontC.Size2{font-size:14px;}.Mags-FontC.Size3{font-size:16px;}.Mags-FontC.Size4{font-size:20px;}.Mags-FontC.Size5{font-size:30px;}.Mags-FontC.Size6{font-size:32px;}.Mags-FontC.Size7{font-size:52px;}',
#          'enable': True,
#          'fdb': False,
#          'flex': 'both',
#          'id': 'SPL',
#          'meta': {'type': 'stream'},
#          'staticLayout': False,
#          'supports': {'cmsg': 1},
#          'uhslot': '.YDC-UH'},
#         'TRADENOW': {'clean': 'cleanTRADENOW',
#          'dest': 'destTRADENOW',
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 55,
#          'id': 'TRADENOW',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 1, 'exp-push': 1},
#          'w': 280},
#         'TRADENOW-1': {'clean': 'cleanTRADENOW-1',
#          'dest': 'destTRADENOW-1',
#          'fdb': True,
#          'flex': {'h': {'max': 280, 'min': 114}, 'ratio': '3.28x1'},
#          'fr': 'expIfr_exp',
#          'h': 114,
#          'id': 'TRADENOW',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 1, 'exp-push': 1, 'resize-to': 1},
#          'w': 320},
#         'UBALDRB': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 90,
#          'id': 'UBALDRB',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 1, 'exp-push': 1},
#          'w': 728},
#         'UBALDRB-9': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 90,
#          'id': 'UBALDRB-9',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 1, 'exp-push': 1},
#          'w': 728},
#         'UBALDRB2': {'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 90,
#          'id': 'UBALDRB2',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 1, 'exp-push': 1},
#          'w': 728},
#         'UBALDRB2-1': {'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 90,
#          'id': 'UBALDRB2-1',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 1, 'exp-push': 1},
#          'w': 728},
#         'UBALDRB2-2': {'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 90,
#          'id': 'UBALDRB2-2',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 1, 'exp-push': 1},
#          'w': 728},
#         'UBALDRB2-3': {'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 90,
#          'id': 'UBALDRB2-3',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 1, 'exp-push': 1},
#          'w': 728},
#         'UBALDRB2-4': {'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 90,
#          'id': 'UBALDRB2-4',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 1, 'exp-push': 1},
#          'w': 728},
#         'UBALREC': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'UBALREC',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300,
#          'z': 3},
#         'UBALREC-1': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'UBALREC-1',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300,
#          'z': 3},
#         'UBALREC-9': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'UBALREC-9',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300,
#          'z': 3},
#         'UBALREC2': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'UBALREC2',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300,
#          'z': 9},
#         'UBALREC2-9': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'UBALREC2-9',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300,
#          'z': 9},
#         'UBALREC3': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'UBALREC3',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300,
#          'z': 9},
#         'UBALREC3-9': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 250,
#          'id': 'UBALREC3-9',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300,
#          'z': 9},
#         'UBAMON': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 600,
#          'id': 'UBAMON',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300,
#          'z': 9},
#         'UBAMON-9': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 600,
#          'id': 'UBAMON-9',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300,
#          'z': 9},
#         'UBAMON2': {'autoFetch': False,
#          'enable': True,
#          'fdb': True,
#          'fr': 'expIfr_exp',
#          'h': 600,
#          'id': 'UBAMON2',
#          'staticLayout': True,
#          'supports': {'exp-ovr': 0, 'exp-push': 1},
#          'w': 300,
#          'z': 9},
#         'WFPAD': {'autoFetch': False,
#          'enable': True,
#          'fdb': False,
#          'fr': 'expIfr_exp',
#          'h': 50,
#          'id': 'WFPAD',
#          'metaSize': True,
#          'staticLayout': False,
#          'supports': {'exp-ovr': 1, 'exp-push': 1, 'lyr': 1, 'resize-to': 1},
#          'w': 320},
#         'WIDGET': {'clean': 'cleanWIDGET',
#          'dest': 'destWIDGET',
#          'flex': {'w': {'max': 800, 'min': 600}},
#          'h': 635,
#          'id': 'WIDGET',
#          'metaSize': False,
#          'w': 650},
#         'WIDGET-1': {'h': 340, 'id': 'WIDGET-1', 'metaSize': False, 'w': 300},
#         'WPS': {'clean': 'cleanWPS',
#          'dest': 'destWPS',
#          'h': 50,
#          'id': 'WPS',
#          'metaSize': True,
#          'w': 320}},
#        'rotationTimingDisabled': False,
#        'timeout': 500,
#        'viewerAdboost': True}},
#      'autoAdRender': True,
#      'cacheDarlaAsset': True,
#      'cacheDarlaConfig': True,
#      'checkForModalClose': True,
#      'customPositionConf': {},
#      'customPositionEnabled': False,
#      'darlaAssetFetch': True,
#      'darlaConfig': {'aboveFoldPositions': 'WPS,MAST,LDRB,SPRZ,SPL,LREC,BTN,BTN-1,BTN-2,BTN-3,BTN1,BTNA,BTNB,BTNC,BTND,FB2,FB2-1,FB2-2,FB2-3,FB2A,FB2B,FB2C,FB2D,NE4,NE4-1,NE4-2,NE4-3,NE4A,NE4B,NE4C,NE4D',
#       'autoRotation': 10000,
#       'debug': False,
#       'dm': 1,
#       'events': {'AUTO': {'autoDDG': 0,
#         'autoIV': 1,
#         'autoMax': 25,
#         'autoRT': 10000,
#         'autoStart': 1,
#         'ddd': 0,
#         'groups': {'LREC3': 'LREC3',
#          'LREC3-9': 'MON2-9',
#          'LREC4': None,
#          'LREC4-9': 'MON2-9',
#          'MON2': 'LREC3',
#          'MON2-9': 'LREC3-9,LREC4-9'},
#         'name': 'AUTO',
#         'npv': 1,
#         'ps': {'BTN': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'BTN-1': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'BTN-2': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'BTN-3': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'BTN-5': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'BTN-6': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'BTN-7': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'BTN-8': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'BTN1': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'BTNA': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'BTNB': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'BTNC': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'BTND': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'FB2': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'FB2-1': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'FB2-2': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'FB2-3': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'FB2A': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'FB2B': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'FB2C': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'FB2D': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LDRB': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LDRB-9': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LDRB2': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LDRB2-1': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LDRB2-2': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LDRB2-9': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LREC': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LREC-9': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LREC2': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LREC2-4': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LREC2-5': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LREC2-6': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LREC2-7': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LREC2-8': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LREC2-9': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LREC3': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LREC3-4': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LREC3-5': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LREC3-6': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LREC3-7': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LREC3-8': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LREC3-9': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LREC4': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'LREC4-9': {'autoIV': 1, 'autoMax': 25, 'autoRT': '35000'},
#          'MAST': {'autoIV': 1, 'autoMax': 25, 'autoRT': 30000},
#          'MAST-9': {'autoIV': 1, 'autoMax': 25, 'autoRT': 30000},
#          'MON': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'MON-1': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'MON2': {'autoRT': 10000},
#          'MON2-9': {'autoRT': 10000},
#          'NE4': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'NE4-1': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'NE4-2': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'NE4-3': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'NE4A': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'NE4B': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'NE4C': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'NE4D': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'SCREC': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000},
#          'SPL': {'autoIV': 1, 'autoMax': 25, 'autoRT': 30000},
#          'TRADENOW': {'autoIV': 1, 'autoMax': 0, 'autoRT': 3600000},
#          'TRADENOW-1': {'autoIV': 1, 'autoMax': 0, 'autoRT': 3600000},
#          'WIDGET': {'autoIV': 1, 'autoMax': 0, 'autoRT': 3600000},
#          'WIDGET-1': {'autoIV': 1, 'autoMax': 0, 'autoRT': 3600000},
#          'WPS': {'autoIV': 1, 'autoMax': 25, 'autoRT': 10000}}},
#        'DEFAULT': {'secure': 1, 'sp': 1183300002, 'ssl': 1},
#        'adFetch': {'dynamic': True,
#         'firstRender': 'FB2A,FB2B,FB2C,FB2D,MON,LDRB,LREC,TRADENOW',
#         'name': 'adFetch',
#         'ps': 'FB2A,FB2B,FB2C,FB2D,MON,LDRB,LREC,LREC2,FOOT,FSRVY,TRADENOW',
#         'sponsoredAds': '',
#         'sponsoredAdsClass': '',
#         'viewportOnly': 'MAST,LDRB,LDRB2,LREC,LREC2,MON,FB2,FB2-1,FB2-2,FB2-3,BTN,BTN-1,BTN-2,BTN-3,BTN1,NE4,NE4-1,NE4-2,NE4-3,WIDGET-1'}},
#       'firstRenderingVisible': True,
#       'k2': {'res': {'pos': ['BTN',
#          'BTN-1',
#          'BTN-2',
#          'BTN-3',
#          'BTN1',
#          'LREC',
#          'LREC2',
#          'LREC3',
#          'LDRB',
#          'MAST'],
#         'rate': 5}},
#       'positions': {'BTN': {'clean': 'cleanBTN',
#         'dest': 'destBTN',
#         'enable': True,
#         'fallback': None,
#         'h': 60,
#         'id': 'BTN',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': True,
#         'staticLayout': False,
#         'w': 120},
#        'BTN-1': {'clean': 'cleanBTN-1',
#         'dest': 'destBTN-1',
#         'enable': True,
#         'fallback': None,
#         'h': 60,
#         'id': 'BTN-1',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': False,
#         'staticLayout': False,
#         'w': 120},
#        'BTN-2': {'clean': 'cleanBTN-2',
#         'dest': 'destBTN-2',
#         'enable': True,
#         'fallback': None,
#         'h': 60,
#         'id': 'BTN-2',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': True,
#         'staticLayout': False,
#         'w': 120},
#        'BTN-3': {'clean': 'cleanBTN-3',
#         'dest': 'destBTN-3',
#         'enable': True,
#         'fallback': None,
#         'h': 60,
#         'id': 'BTN-3',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': True,
#         'staticLayout': False,
#         'w': 120},
#        'BTN-5': {'clean': 'cleanBTN-5',
#         'dest': 'destBTN-5',
#         'enable': True,
#         'fallback': None,
#         'h': 60,
#         'id': 'BTN-5',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': True,
#         'staticLayout': False,
#         'w': 120},
#        'BTN-6': {'clean': 'cleanBTN-6',
#         'dest': 'destBTN-6',
#         'enable': True,
#         'fallback': None,
#         'h': 60,
#         'id': 'BTN-6',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': True,
#         'staticLayout': False,
#         'w': 120},
#        'BTN-7': {'clean': 'cleanBTN-7',
#         'dest': 'destBTN-7',
#         'enable': True,
#         'fallback': None,
#         'h': 60,
#         'id': 'BTN-7',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': True,
#         'staticLayout': False,
#         'w': 120},
#        'BTN-8': {'clean': 'cleanBTN-8',
#         'dest': 'destBTN-8',
#         'enable': True,
#         'fallback': None,
#         'h': 60,
#         'id': 'BTN-8',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': True,
#         'staticLayout': False,
#         'w': 120},
#        'BTN1': {'clean': 'cleanBTN1',
#         'dest': 'destBTN1',
#         'enable': True,
#         'fallback': None,
#         'h': 60,
#         'id': 'BTN1',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': True,
#         'staticLayout': False,
#         'w': 120},
#        'BTN1-1': {'clean': 'cleanBTN1-1',
#         'dest': 'destBTN1-1',
#         'enable': True,
#         'fallback': None,
#         'h': 60,
#         'id': 'BTN1',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': True,
#         'staticLayout': False,
#         'w': 120},
#        'BTNA': {'clean': 'cleanBTNA',
#         'dest': 'destBTNA',
#         'enable': True,
#         'fallback': None,
#         'h': 60,
#         'id': 'BTNA',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': True,
#         'staticLayout': False,
#         'w': 120},
#        'BTNB': {'clean': 'cleanBTNB',
#         'dest': 'destBTNB',
#         'enable': True,
#         'fallback': None,
#         'h': 60,
#         'id': 'BTNB',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': True,
#         'staticLayout': False,
#         'w': 120},
#        'BTNC': {'clean': 'cleanBTNC',
#         'dest': 'destBTNC',
#         'enable': True,
#         'fallback': None,
#         'h': 60,
#         'id': 'BTNC',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': True,
#         'staticLayout': False,
#         'w': 120},
#        'BTND': {'clean': 'cleanBTND',
#         'dest': 'destBTND',
#         'enable': True,
#         'fallback': None,
#         'h': 60,
#         'id': 'BTND',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': True,
#         'staticLayout': False,
#         'w': 120},
#        'DEFAULT': {'clean': 'cleanDEFAULT',
#         'dest': 'destDEFAULT',
#         'enable': True,
#         'fallback': None,
#         'id': 'DEFAULT',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': False,
#         'name': 'DEFAULT',
#         'staticLayout': False},
#        'FB2': {'clean': 'cleanFB2',
#         'dest': 'destFB2',
#         'enable': True,
#         'fallback': None,
#         'h': 60,
#         'id': 'FB2',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': True,
#         'staticLayout': False,
#         'w': 120},
#        'FB2-1': {'clean': 'cleanFB2-1',
#         'dest': 'destFB2-1',
#         'enable': True,
#         'fallback': None,
#         'h': 60,
#         'id': 'FB2-1',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': True,
#         'staticLayout': False,
#         'w': 120},
#        'FB2-2': {'clean': 'cleanFB2-2',
#         'dest': 'destFB2-2',
#         'enable': True,
#         'fallback': None,
#         'h': 60,
#         'id': 'FB2-2',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': True,
#         'staticLayout': False,
#         'w': 120},
#        'FB2-3': {'clean': 'cleanFB2-3',
#         'dest': 'destFB2-3',
#         'enable': True,
#         'fallback': None,
#         'h': 60,
#         'id': 'FB2-3',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': True,
#         'staticLayout': False,
#         'w': 120},
#        'FB2A': {'clean': 'cleanFB2A',
#         'dest': 'destFB2A',
#         'enable': True,
#         'failed': True,
#         'fallback': None,
#         'h': 60,
#         'id': 'FB2A',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': True,
#         'staticLayout': False,
#         'w': 120},
#        'FB2B': {'clean': 'cleanFB2B',
#         'dest': 'destFB2B',
#         'enable': True,
#         'failed': True,
#         'fallback': None,
#         'h': 60,
#         'id': 'FB2B',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': True,
#         'staticLayout': False,
#         'w': 120},
#        'FB2C': {'clean': 'cleanFB2C',
#         'dest': 'destFB2C',
#         'enable': True,
#         'failed': True,
#         'fallback': None,
#         'h': 60,
#         'id': 'FB2C',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': True,
#         'staticLayout': False,
#         'w': 120},
#        'FB2D': {'clean': 'cleanFB2D',
#         'dest': 'destFB2D',
#         'enable': True,
#         'failed': True,
#         'fallback': None,
#         'h': 60,
#         'id': 'FB2D',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': True,
#         'staticLayout': False,
#         'w': 120},
#        'FOOT': {'clean': 'cleanFOOT',
#         'dest': 'destFOOT',
#         'enable': True,
#         'failed': True,
#         'fallback': None,
#         'fr': 'expIfr_exp',
#         'id': 'FOOT',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': False,
#         'staticLayout': False},
#        'FSRVY': {'clean': 'cleanFSRVY',
#         'dest': 'destFSRVY',
#         'enable': True,
#         'fallback': None,
#         'fr': 'expIfr_exp',
#         'id': 'FSRVY',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': False,
#         'staticLayout': False},
#        'INARTICLE': {'autoFetch': False,
#         'clean': 'cleanINARTICLE',
#         'dest': 'destINARTICLE',
#         'enable': True,
#         'fallback': None,
#         'flex': {'h': {'min': 5}, 'ratio': '1.78x1', 'w': {'min': 10}},
#         'fr': 'expIfr_exp',
#         'h': 211,
#         'id': 'INARTICLE',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': False,
#         'staticLayout': True,
#         'supports': {'exp-ovr': 1, 'exp-push': 1},
#         'w': 375,
#         'z': 9},
#        'LDRB': {'clean': 'cleanLDRB',
#         'dest': 'destLDRB',
#         'enable': True,
#         'failed': True,
#         'fallback': None,
#         'fdb': True,
#         'fr': 'expIfr_exp',
#         'h': 90,
#         'id': 'LDRB',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': False,
#         'staticLayout': True,
#         'supports': {'exp-ovr': 1, 'exp-push': 1},
#         'w': 728},
#        'LDRB-9': {'clean': 'cleanLDRB-9',
#         'dest': 'destLDRB-9',
#         'enable': True,
#         'fallback': None,
#         'fdb': True,
#         'fr': 'expIfr_exp',
#         'h': 90,
#         'id': 'LDRB-9',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': False,
#         'staticLayout': True,
#         'supports': {'exp-ovr': 1, 'exp-push': 1},
#         'w': 728},
#        'LDRB2': {'clean': 'cleanLDRB2',
#         'dest': 'destLDRB2',
#         'enable': True,
#         'fallback': None,
#         'fdb': True,
#         'fr': 'expIfr_exp',
#         'h': 90,
#         'id': 'LDRB2',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': False,
#         'staticLayout': True,
#         'supports': {'exp-ovr': 1, 'exp-push': 1},
#         'w': 728},
#        'LDRB2-1': {'clean': 'cleanLDRB2-1',
#         'dest': 'destLDRB2-1',
#         'enable': True,
#         'fallback': None,
#         'fdb': True,
#         'fr': 'expIfr_exp',
#         'h': 90,
#         'id': 'LDRB2-1',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': False,
#         'staticLayout': True,
#         'supports': {'exp-ovr': 1, 'exp-push': 1},
#         'w': 728},
#        'LDRB2-2': {'clean': 'cleanLDRB2-2',
#         'dest': 'destLDRB2-2',
#         'enable': True,
#         'fallback': None,
#         'fdb': True,
#         'fr': 'expIfr_exp',
#         'h': 90,
#         'id': 'LDRB2-2',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': False,
#         'staticLayout': True,
#         'supports': {'exp-ovr': 1, 'exp-push': 1},
#         'w': 728},
#        'LDRB2-3': {'clean': 'cleanLDRB2-3',
#         'dest': 'destLDRB2-3',
#         'enable': True,
#         'fallback': None,
#         'fdb': True,
#         'fr': 'expIfr_exp',
#         'h': 90,
#         'id': 'LDRB2-3',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': False,
#         'staticLayout': True,
#         'supports': {'exp-ovr': 1, 'exp-push': 1},
#         'w': 728},
#        'LDRB2-4': {'clean': 'cleanLDRB2-4',
#         'dest': 'destLDRB2-4',
#         'enable': True,
#         'fallback': None,
#         'fdb': True,
#         'fr': 'expIfr_exp',
#         'h': 90,
#         'id': 'LDRB2-4',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': False,
#         'staticLayout': True,
#         'supports': {'exp-ovr': 1, 'exp-push': 1},
#         'w': 728},
#        'LREC': {'clean': 'cleanLREC',
#         'dest': 'destLREC',
#         'doubleBuffering': False,
#         'enable': True,
#         'failed': True,
#         'fallback': None,
#         'fdb': True,
#         'fr': 'expIfr_exp',
#         'h': 250,
#         'id': 'LREC',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': False,
#         'staticLayout': True,
#         'supports': {'exp-ovr': 0, 'exp-push': 1},
#         'w': 300},
#        'LREC-9': {'clean': 'cleanLREC-9',
#         'dest': 'destLREC-9',
#         'enable': True,
#         'fallback': None,
#         'fdb': True,
#         'fr': 'expIfr_exp',
#         'h': 250,
#         'id': 'LREC-9',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': False,
#         'staticLayout': True,
#         'supports': {'exp-ovr': 0, 'exp-push': 1},
#         'w': 300},
#        'LREC2': {'clean': 'cleanLREC2',
#         'dest': 'destLREC2',
#         'enable': True,
#         'failed': True,
#         'fallback': None,
#         'fdb': True,
#         'fr': 'expIfr_exp',
#         'h': 250,
#         'id': 'LREC2',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': False,
#         'staticLayout': True,
#         'supports': {'exp-ovr': 0, 'exp-push': 1},
#         'w': 300},
#        'LREC2-4': {'autoFetch': False,
#         'clean': 'cleanLREC2-4',
#         'dest': 'destLREC2-4',
#         'enable': True,
#         'fallback': None,
#         'fdb': True,
#         'fr': 'expIfr_exp',
#         'h': 250,
#         'id': 'LREC2-4',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': False,
#         'staticLayout': True,
#         'supports': {'exp-ovr': 0, 'exp-push': 1},
#         'w': 300,
#         'z': 9},
#        'LREC2-5': {'autoFetch': False,
#         'clean': 'cleanLREC2-5',
#         'dest': 'destLREC2-5',
#         'enable': True,
#         'fallback': None,
#         'fdb': True,
#         'fr': 'expIfr_exp',
#         'h': 250,
#         'id': 'LREC2-5',
#         'meta': {'hostURL': 'https://finance.yahoo.com/quote/AAPL/analysis'},
#         'metaSize': False,
#         'staticLayout': True,
#         'supports': {'exp-ovr': 0, 'exp-push': 1},
#         'w': 300,
#         'z': 9},
#        'LREC2-6': {'autoFetch': False,
#         'clean': 'cleanLREC2-6',
#         'dest': 'destLREC2-6',
#         'enable': True,
# ...
#      'intl': 'us',
#      'lang': 'en-US',
#      'partner': 'none',
#      'prid': '66j1oitgdmc15',
#      'region': 'US',
#      'site': 'finance',
#      'tz': 'America/New_York',
#      'ver': '0.102.4924'}},
#    'SessionPlugin': {'bucketLogString': 'finance-US-en-US-def',
#     'bucketMetaData': {},
#     'consent': {},
#     'dabState': '',
#     'dimensions': {'authed': '0',
#      'bot': '1',
#      'bucket': 'finance-US-en-US-def',
#      'colo': 'bf1',
#      'device': 'desktop',
#      'ecma': 'default',
#      'environment': 'prod',
#      'feature': ['adsMigration',
#       'canvassOffnet',
#       'ccOnMute',
#       'disableCommentsMessage',
#       'debouncesearch100',
#       'deferDarla',
#       'ecmaModern',
#       'emptyServiceWorker',
#       'enable3pConsent',
#       'enableCCPAFooter',
#       'enableCMP',
#       'enableConsentData',
#       'enableFeatureTours',
#       'enableFinancialsTemplate',
#       'enableFreeFinRichSearch',
#       'enableGuceJs',
#       'enableGuceJsOverlay',
#       'enableNavFeatureCue',
#       'enableNewResearchInsights',
#       'enablePfSummaryForEveryone',
#       'enablePremiumSingleCTA',
#       'enablePrivacyUpdate',
#       'enableRebranding',
#       'enableStreamDebounce',
#       'enableTheming',
#       'enableUpgradeLeafPage',
#       'enableVideoURL',
#       'enableXrayNcp',
#       'enableXrayNcpInModal',
#       'enableXrayTickerEntities',
#       'enableYahooSans',
#       'enableYodleeErrorMsgCriOS',
#       'ncpListStream',
#       'ncpPortfolioStream',
#       'ncpQspStream',
#       'ncpStream',
#       'ncpStreamIntl',
#       'ncpTopicStream',
#       'newContentAttribution',
#       'newLogo',
#       'oathPlayer',
#       'optimizeSearch',
#       'premium35',
#       'relatedVideoFeature',
#       'threeAmigos',
#       'waferHeader',
#       'useNextGenHistory',
#       'videoNativePlaylist',
#       'sunsetMotif2',
#       'enableUserPrefAPI',
#       'livecoverage',
#       'darlaFirstRenderingVisible',
#       'enableAdlite',
#       'enableTradeit',
#       'enableFeatureBar',
#       'enableSearchEnhancement',
#       'enableUserSentiment',
#       'enableBankrateWidget',
#       'enableYodlee',
#       'canvassReplies',
#       'enablePremiumFinancials',
#       'enableInstapage',
#       'enableNewResearchFilterMW',
#       'showExpiredIdeas',
#       'showMorningStar',
#       'enableSEOResearchReport',
#       'enableSingleRail',
#       'enableUpgrade',
#       'enableAmexOffer',
#       'enableUserInsights',
#       'enhanceAddToWL',
#       'article2_csn',
#       'sponsoredAds',
#       'enableStageAds',
#       'enableTradeItLinkBrokerSecondaryPromo',
#       'enableQspPremiumPromoSmall',
#       'clientDelayNone',
#       'threeAmigosMabEnabled',
#       'threeAmigosAdsEnabledAndStreamIndex0',
#       'enableRelatedTickers',
#       'enableTasteMaker',
#       'enableNotification',
#       'enableJSErrorBeacon',
#       'financeRightRailA20',
#       'enableBrokerCenter',
#       'enableYahooPlus',
#       'enablePremiumUpsell'],
#      'intl': 'us',
#      'lang': 'en-US',
#      'mode': 'normal',
#      'nps': {},
#      'partner': 'none',
#      'region': 'US',
#      'site': 'finance',
#      'spdy': '0',
#      'ssl': '1',
#      'theme': 'none',
#      'tpConsent': True,
#      'tz': 'America/New_York',
#      'ynet': '0',
#      'ytee': '0'},
#     'enableSpdyAssetUrls': False,
#     'enableSpdyAssetUrlsFlag': False,
#     'experimentIds': {},
#     'host': 'finance.yahoo.com',
#     'isBot': True,
#     'isCorpUser': False,
#     'isDevInfo': False,
#     'isYnet': False,
#     'pathPrefix': '/_finance_doubledown',
#     'protocol': 'https',
#     'query': {'p': 'AAPL'},
#     'rid': '66j1oitgdmc15',
#     'sampleIds': {},
#     'spdyPathPrefix': '/sy',
#     'userAgent': {'browserName': '',
#      'browserVersion': '',
#      'osName': '',
#      'osVersion': ''},
#     'woe': {'confidence_country': '100',
#      'confidence_state': '100',
#      'country': 'US',
#      'state': 'SC',
#      'woeid_country': '23424977',
#      'woeid_state': '2347599',
#      'zip_woeid': '12770163'}}}},
#  'plugins': {'BundlePlugin': {'mainBundle': 'td-app-finance'},
#   'ResourcePlugin': {'options': {'defaultBundle': 'td-app-finance'},
#    'registry': {'configs': {'Calendar': {'componentCalEvents': 1},
#      'CuratedWatchlists': {'listColumns': 1},
#      'DataUtility': {'componentDataUtility': 1, 'dataUtilityConfig': 1},
#      'EventSplash': {'componentEventSplash': 1},
#      'Events': {'componentEvents': 1, 'componentWebinars': 1},
#      'FullScreenChartIQPage': {'componentFullScreenChart': 1},
#      'Industry': {'componentIndustry': 1, 'sectorsList': 1},
#      'Lookup': {'listColumns': 1},
#      'Portfolio': {'componentPortfolios': 1, 'currencies': 1},
#      'PremiumSplash': {'componentPremiumSplash': 1},
#      'Quote': {'componentQuote': 1,
#       'equityKeyStatistics': 1,
#       'esg': 1,
#       'etfKeyStatistics': 1,
#       'financials/balanceSheet': 1,
#       'financials/balanceSheet_B': 1,
#       'financials/balanceSheet_I': 1,
#       'financials/balanceSheet_M': 1,
#       'financials/balanceSheet_N': 1,
#       'financials/balanceSheet_T': 1,
#       'financials/balanceSheet_U': 1,
#       'financials/cashFlow': 1,
#       'financials/cashFlow_B': 1,
#       'financials/cashFlow_I': 1,
#       'financials/cashFlow_M': 1,
#       'financials/cashFlow_N': 1,
#       'financials/cashFlow_T': 1,
#       'financials/cashFlow_U': 1,
#       'financials/cashflowStatement': 1,
#       'financials/incomeStatement': 1,
#       'financials/incomeStatement_B': 1,
#       'financials/incomeStatement_I': 1,
#       'financials/incomeStatement_M': 1,
#       'financials/incomeStatement_N': 1,
#       'financials/incomeStatement_T': 1,
#       'financials/incomeStatement_U': 1,
#       'financials/templates': 1,
#       'holders': 1,
#       'keyStatistics': 1,
#       'mockPremiumData': 1,
#       'mutualFundKeyStatistics': 1,
#       'qsp/equity': 1,
#       'qsp/etfHolding': 1,
#       'qsp/etfPerformance': 1,
#       'qsp/etfProfile': 1,
#       'qsp/mutualFundHolding': 1,
#       'qsp/mutualFundPerformance': 1,
#       'qsp/mutualFundProfile': 1,
#       'qsp/mutualFundPurchaseInfo': 1,
#       'qsp/mutualFundRisk': 1},
#      'QuotePage': {'componentNavHeader': 1,
#       'componentQuoteECDWrapper': 1,
#       'componentQuoteHeader': 1,
#       'componentQuoteNav': 1,
#       'quoteSummaryColumnLayout': 1},
#      'RatesPage': {'rateIframeMap': 1},
#      'Research': {'componentResearch': 1, 'filters': 1, 'reportConf': 1},
#      'SECFilings': {'mockSECFilingData': 1, 'mockSECFilingDataQuotePage': 1},
#      'Screener': {'componentScreener': 1, 'componentScreenerTable': 1},
#      'Trumponomics': {'componentTrumponomics': 1, 'previousPresidentData': 1},
#      'Videos': {'componentVideos': 1, 'componentVideosNav': 1},
#      'express-premium-subscriptions': {'skuMapping': 1},
#      'react-avatar': {'defaultColors': 1},
#      'react-finance': {'app': 1,
#       'atomize': 1,
#       'componentFooter': 1,
#       'componentNavHelper': 1,
#       'componentNotificationAlert': 1,
#       'componentPremiumUpsell': 1,
#       'componentQuoteSummaryPreview': 1,
#       'componentSignInBtn': 1,
#       'componentUH': 1,
#       'cookies': 1,
#       'defaultViews': 1,
#       'i13n': 1,
#       'industries': 1,
#       'listConfig': 1,
#       'styles/common': 1},
#      'react-tile': {'config': 1},
#      'react-video': {'ve-module': 1, 'video-reel': 1},
#      'sports-ybar-utils': {'app': 1, 'navDropdown': 1, 'wafer': 1},
#      'td-app-finance': {'US_strings': 1,
#       'ads': 1,
#       'aft': 1,
#       'app': 1,
#       'appletOverrides/tdv2-wafer-header/componentMailPreview': 1,
#       'assets': 1,
#       'atomic/atomizer-config': 1,
#       'atomic/themes/dark': 1,
#       'atomic/themes/light': 1,
#       'atomize': 1,
#       'autocomplete': 1,
#       'beacon': 1,
#       'bundles/config': 1,
#       'cdn': 1,
#       'constants': 1,
#       'cookies': 1,
#       'csp-policy': 1,
#       'dimensions': 1,
#       'feature': 1,
#       'i13n': 1,
#       'louter': 1,
#       'marketdata': 1,
#       'monalixa': 1,
#       'themes/premium': 1,
#       'topics': 1,
#       'ui': 1,
#       'videoreel': 1},
#      'td-service-canvas': {'config': 1},
#      'td-service-canvass': {'api': 1},
#      'td-service-darla': {'config': 1},
#      'tdv2-applet-account-switch': {'componentAccountSwitch': 1, 'i13n': 1},
#      'tdv2-applet-canvass': {'app': 1,
#       'atomize': 1,
#       'componentCanvassMessage': 1,
#       'componentComments': 1},
#      'tdv2-applet-channels': {'componentChannels': 1, 'thumbnails': 1},
#      'tdv2-applet-content-caas': {'componentContentCaas': 1},
#      'tdv2-applet-discussion': {'componentDiscussionCarousel': 1,
#       'componentDiscussionList': 1},
#      'tdv2-applet-featurebar': {'componentFeatureBar': 1,
#       'componentFeatureBarSmartphone': 1},
#      'tdv2-applet-follow': {'componentFollow': 1, 'regal': 1},
#      'tdv2-applet-native-ads': {'componentGeminiDeals': 1,
#       'componentPencilAd': 1,
#       'componentSponsoredAd': 1},
#      'tdv2-applet-navrail': {'componentNavLite': 1,
#       'nav/desktop': 1,
#       'nav/device/index': 1,
#       'nav/index': 1,
#       'nav/lang/index': 1,
#       'nav/master': 1,
#       'nav/partner/index': 1,
#       'nav/site/autos': 1,
#       'nav/site/beauty': 1,
#       'nav/site/celebrity': 1,
#       'nav/site/cricket': 1,
#       'nav/site/entertainment': 1,
#       'nav/site/finance': 1,
#       'nav/site/food': 1,
#       'nav/site/fp': 1,
#       'nav/site/gma': 1,
#       'nav/site/hkstylemen': 1,
#       'nav/site/hktravelnow': 1,
#       'nav/site/index': 1,
#       'nav/site/ivy': 1,
#       'nav/site/katiecouric': 1,
#       'nav/site/lifestyle': 1,
#       'nav/site/m6info': 1,
#       'nav/site/movies': 1,
#       'nav/site/music': 1,
#       'nav/site/news': 1,
#       'nav/site/saludbucal': 1,
#       'nav/site/saudebucal': 1,
#       'nav/site/sports': 1,
#       'nav/site/style': 1,
#       'nav/site/tech': 1,
#       'nav/site/travel': 1,
#       'nav/site/tv': 1,
#       'nav/site/weather': 1,
#       'nav/site/yourfinancialjourney': 1,
#       'nav/smartphone': 1,
#       'nav/tablet': 1},
#      'tdv2-applet-rawads': {'componentRawAds': 1},
#      'tdv2-applet-rmp': {'componentRmp': 1, 'redis': 1},
#      'tdv2-applet-search-input': {'searchassist': 1},
#      'tdv2-applet-sponsored-moments': {'componentDesktopMomentsAd': 1,
#       'componentReserveMomentsAdWrapper': 1,
#       'componentSponsoredMomentsAd': 1,
#       'componentSponsoredMomentsAdWafer': 1,
#       'componentSponsoredMomentsCaas': 1,
#       'wafer': 1},
#      'tdv2-applet-stream': {'componentStream': 1},
#      'tdv2-applet-stream-hero': {'componentFeaturedHero': 1,
#       'componentStreamHero': 1,
#       'componentStreamHeroCarousel': 1,
#       'componentWideHero': 1},
#      'tdv2-applet-swisschamp': {'componentBookmarkButton': 1},
#      'tdv2-applet-uh': {'componentHeader': 1,
#       'components/device/index': 1,
#       'components/environment/index': 1,
#       'components/index': 1,
#       'components/lang/index': 1,
#       'components/master': 1,
#       'components/partner/index': 1,
#       'components/site/index': 1,
#       'searchOrigins': 1},
#      'tdv2-applet-userintent': {'componentUserintent': 1},
#      'tdv2-applet-video-lightbox': {'componentContentLightboxVideo': 1,
#       'componentVideoLightbox': 1},
#      'tdv2-applet-video-modal': {'componentVideoModal': 1,
#       'keyboard-shortcuts': 1,
#       'modalShareButtons': 1,
#       'thumbnails': 1,
#       'thumbnails-cover': 1,
#       'videoModalExamples': 1},
#      'tdv2-service-ads': {'config': 1},
#      'tdv2-service-caas': {'content': 1, 'dimensions': 1, 'sidekick': 1},
#      'tdv2-service-cds': {'config': 1},
#      'tdv2-wafer-adfeedback': {'adLiteFeedbackConfig': 1,
#       'app': 1,
#       'wafer': 1},
#      'tdv2-wafer-header': {'aol-channels': 1,
#       'app': 1,
#       'assets/AssistJs': 1,
#       'assets/AssistJs-v1': 1,
#       'assets/Logo': 1,
#       'assets/NavigationScrollHandler': 1,
#       'assets/NotificationClient': 1,
#       'assets/PanelItems': 1,
#       'componentHeader': 1,
#       'componentHeaderDesktop': 1,
#       'componentHeaderIntl': 1,
#       'componentHeaderTablet': 1,
#       'componentHeaderYBar': 1,
#       'componentLockerCheckIn': 1,
#       'componentMailCount': 1,
#       'componentMailPreview': 1,
#       'componentMailPreviewMyYahoo': 1,
#       'componentMailPreviewOptIn': 1,
#       'dimensions': 1,
#       'headerDesktop/ar-JO': 1,
#       'headerDesktop/de-DE': 1,
#       'headerDesktop/el-GR': 1,
#       'headerDesktop/en-AE': 1,
#       'headerDesktop/en-AU': 1,
#       'headerDesktop/en-GB': 1,
#       'headerDesktop/en-IE': 1,
#       'headerDesktop/en-IN': 1,
#       'headerDesktop/en-MY': 1,
#       'headerDesktop/en-NZ': 1,
#       'headerDesktop/en-PH': 1,
#       'headerDesktop/en-SG': 1,
#       'headerDesktop/en-ZA': 1,
#       'headerDesktop/es-ES': 1,
#       'headerDesktop/es-US': 1,
#       'headerDesktop/fr-BE': 1,
#       'headerDesktop/fr-FR': 1,
#       'headerDesktop/id-ID': 1,
#       'headerDesktop/index': 1,
#       'headerDesktop/it-IT': 1,
#       'headerDesktop/nl-BE': 1,
#       'headerDesktop/pt-BR': 1,
#       'headerDesktop/ro-RO': 1,
#       'headerDesktop/sv-SE': 1,
#       'headerDesktop/vi-VN': 1,
#       'styles/AccordionPanelItem': 1,
#       'styles/Ads': 1,
#       'styles/BackButton': 1,
#       'styles/BackButtonNew': 1,
#       'styles/Dialogue': 1,
#       'styles/GetApp': 1,
#       'styles/Handwrite': 1,
#       'styles/Header': 1,
#       'styles/HeaderDesktop': 1,
#       'styles/HeaderTablet': 1,
#       'styles/Logo': 1,
#       'styles/LogoNew': 1,
#       'styles/MailCount': 1,
#       'styles/MailMenu': 1,
#       'styles/MailPreview': 1,
#       'styles/MailPreviewMyYahoo': 1,
#       'styles/MailPreviewOptIn': 1,
#       'styles/NavigationBar': 1,
#       'styles/NotificationMenu': 1,
#       'styles/ProfileButton': 1,
#       'styles/ProfileMenu': 1,
#       'styles/ProfilePanel': 1,
#       'styles/SearchAssist': 1,
#       'styles/SearchBox': 1,
#       'styles/SearchButton': 1,
#       'styles/SearchKeyword': 1,
#       'styles/SimplePanelItem': 1,
#       'styles/SkipLinks': 1,
#       'styles/Tooltip': 1,
#       'styles/TopBar': 1,
#       'styles/WeatherMenu': 1,
#       'styles/index': 1,
#       'utils/getAtomicClassNames': 1,
#       'wafer': 1},
#      'tdv2-wafer-utils': {'componentGtmPixel': 1,
#       'styles/tabs': 1,
#       'wafer': 1},
#      'tdv2-wafer-viewer': {'dimensions': 1, 'wafer': 1},
#      'vertical-video-util': {'category': 1},
#      'video-service': {'channel_service_config': 1}},
#     'lang': {'react-finance': {'strings': 1},
#      'react-tumblr-tile': {'strings': 1},
#      'td-ads': {'strings': 1},
#      'td-app-finance': {'strings': 1},
#      'tdv2-applet-account-switch': {'strings': 1},
#      'tdv2-applet-canvass': {'strings': 1},
#      'tdv2-applet-channels': {'strings': 1},
#      'tdv2-applet-content-caas': {'strings': 1},
#      'tdv2-applet-discussion': {'strings': 1},
#      'tdv2-applet-featurebar': {'strings': 1},
#      'tdv2-applet-follow': {'strings': 1},
#      'tdv2-applet-native-ads': {'strings': 1},
#      'tdv2-applet-navrail': {'strings': 1},
#      'tdv2-applet-rawads': {'strings': 1},
#      'tdv2-applet-search-input': {'strings': 1},
#      'tdv2-applet-sponsored-moments': {'strings': 1},
#      'tdv2-applet-stream': {'strings': 1},
#      'tdv2-applet-stream-hero': {'strings': 1},
#      'tdv2-applet-swisschamp': {'strings': 1},
#      'tdv2-applet-uh': {'strings': 1},
#      'tdv2-applet-userintent': {'strings': 1},
#      'tdv2-applet-video-lightbox': {'strings': 1},
#      'tdv2-applet-video-modal': {'strings': 1},
#      'tdv2-wafer-adfeedback': {'strings': 1},
#      'tdv2-wafer-header': {'strings': 1},
#      'tdv2-wafer-utils': {'strings': 1},
#      'yahoodotcom-layout': {'strings': 1}}}}}}

# %%
upgrades_and_downgrades = data['context']['dispatcher']['stores']['QuoteSummaryStore']['upgradeDowngradeHistory']['history']
df = pd.DataFrame(upgrades_and_downgrades)

# %%
df
# Out:
#      epochGradeDate                    firm       toGrade fromGrade action
# 0        1624534652          Morgan Stanley    Overweight             main
# 1        1622201116     New Street Research          Sell   Neutral   down
# 2        1621421955                Barclays  Equal-Weight             main
# 3        1619704919                Barclays  Equal-Weight             main
# 4        1619703632  Monness, Crespi, Hardt           Buy             main
# ..              ...                     ...           ...       ...    ...
# 787      1331713260       Canaccord Genuity           Buy             main
# 788      1331705580          Morgan Stanley    Overweight             main
# 789      1331618880               Jefferies           Buy             main
# 790      1331191980          FBN Securities    Outperform             main
# 791      1328775420       Canaccord Genuity           Buy             main
#
# [792 rows x 5 columns]

# %%
df['date'] = pd.to_datetime(df['epochGradeDate'], unit='s')
df = df.drop(columns=['epochGradeDate'])

# %%
df
# Out:
#                        firm       toGrade fromGrade action                date
# 0            Morgan Stanley    Overweight             main 2021-06-24 11:37:32
# 1       New Street Research          Sell   Neutral   down 2021-05-28 11:25:16
# 2                  Barclays  Equal-Weight             main 2021-05-19 10:59:15
# 3                  Barclays  Equal-Weight             main 2021-04-29 14:01:59
# 4    Monness, Crespi, Hardt           Buy             main 2021-04-29 13:40:32
# ..                      ...           ...       ...    ...                 ...
# 787       Canaccord Genuity           Buy             main 2012-03-14 08:21:00
# 788          Morgan Stanley    Overweight             main 2012-03-14 06:13:00
# 789               Jefferies           Buy             main 2012-03-13 06:08:00
# 790          FBN Securities    Outperform             main 2012-03-08 07:33:00
# 791       Canaccord Genuity           Buy             main 2012-02-09 08:17:00
#
# [792 rows x 5 columns]

# %%
action_map = {
    'init': 'initiated',
    'down': 'downgrade',
    'reit': 'reiterates',
    'up': 'upgrade',
    'main': 'maintains'
}


for key, value in action_map.items():
    df.replace(key, value, inplace=True)

# %%
df
# Out:
#                        firm       toGrade  ...     action                date
# 0            Morgan Stanley    Overweight  ...  maintains 2021-06-24 11:37:32
# 1       New Street Research          Sell  ...  downgrade 2021-05-28 11:25:16
# 2                  Barclays  Equal-Weight  ...  maintains 2021-05-19 10:59:15
# 3                  Barclays  Equal-Weight  ...  maintains 2021-04-29 14:01:59
# 4    Monness, Crespi, Hardt           Buy  ...  maintains 2021-04-29 13:40:32
# ..                      ...           ...  ...        ...                 ...
# 787       Canaccord Genuity           Buy  ...  maintains 2012-03-14 08:21:00
# 788          Morgan Stanley    Overweight  ...  maintains 2012-03-14 06:13:00
# 789               Jefferies           Buy  ...  maintains 2012-03-13 06:08:00
# 790          FBN Securities    Outperform  ...  maintains 2012-03-08 07:33:00
# 791       Canaccord Genuity           Buy  ...  maintains 2012-02-09 08:17:00
#
# [792 rows x 5 columns]

# %%
df = df[['date', 'firm', 'action', 'fromGrade', 'toGrade']]

# %%
df
# Out:
#                    date                    firm  ... fromGrade       toGrade
# 0   2021-06-24 11:37:32          Morgan Stanley  ...              Overweight
# 1   2021-05-28 11:25:16     New Street Research  ...   Neutral          Sell
# 2   2021-05-19 10:59:15                Barclays  ...            Equal-Weight
# 3   2021-04-29 14:01:59                Barclays  ...            Equal-Weight
# 4   2021-04-29 13:40:32  Monness, Crespi, Hardt  ...                     Buy
# ..                  ...                     ...  ...       ...           ...
# 787 2012-03-14 08:21:00       Canaccord Genuity  ...                     Buy
# 788 2012-03-14 06:13:00          Morgan Stanley  ...              Overweight
# 789 2012-03-13 06:08:00               Jefferies  ...                     Buy
# 790 2012-03-08 07:33:00          FBN Securities  ...              Outperform
# 791 2012-02-09 08:17:00       Canaccord Genuity  ...                     Buy
#
# [792 rows x 5 columns]

# %%
df.to_excel('aapl-upgrades-downgrades.xlsx')

# %%
df.shape
# Out:
# (792, 5)

# %%
df.columns
# Out:
# Index(['date', 'firm', 'action', 'fromGrade', 'toGrade'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       792 non-null    datetime64[ns]
#  1   firm       792 non-null    object
#  2   action     792 non-null    object
#  3   fromGrade  792 non-null    object
#  4   toGrade    792 non-null    object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 31.1+ KB

# %%
df.firm.value_counts()
# Out:
# Morgan Stanley         53
# Barclays               39
# Canaccord Genuity      39
# UBS                    34
# Nomura                 32
#                        ..
# Morgan Keegan           1
# Phillip Securities      1
# Oxen Group              1
# New Street Research     1
# Sterne Agee CRT         1
# Name: firm, Length: 93, dtype: int64

# %%
df.action.value_counts()
# Out:
# maintains     613
# downgrade      63
# upgrade        49
# initiated      44
# reiterates     23
# Name: action, dtype: int64

# %%
df.fromGrade.value_counts()
# Out:
#                   602
# Buy                61
# Outperform         29
# Neutral            23
# Overweight         23
# Hold               16
# Market Perform     16
# Equal-Weight        5
# Strong Buy          4
# Long-Term Buy       3
# Sell                3
# Sector Weight       2
# Accumulate          1
# Perform             1
# Reduce              1
# Equal-weight        1
# Sector Perform      1
# Name: fromGrade, dtype: int64

# %%
df.toGrade.value_counts()
# Out:
# Buy                  306
# Outperform           158
# Overweight           122
# Neutral               81
# Hold                  39
# Market Perform        24
# Equal-Weight          19
# Sell                   8
# Strong Buy             8
# Positive               4
# Sector Perform         4
#                        3
# Market Outperform      3
# Perform                2
# Sector Outperform      2
# Sector Weight          2
# Long-Term Buy          1
# Long-term Buy          1
# Underweight            1
# Negative               1
# Equal-weight           1
# Reduce                 1
# Underperform           1
# Name: toGrade, dtype: int64
